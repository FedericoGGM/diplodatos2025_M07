# %% [markdown]
# **El Impacto De Las Condiciones Ambientales**
#
# ---
#
#
# En la Calidad Del Agua Del Río De La Plata

# %% [markdown]
# [texto del vínculo](https://)

# %%
#Librerias

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from IPython.display import display, HTML
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Pandas permite cargar, explorar y manipular datos en estructuras como los DataFrames, que son fundamentales para trabajar con información tabular. numpy se emplea para operaciones numéricas eficientes, como cálculos con arrays y manejo de valores nulos. Para la visualización de datos, se usa matplotlib.pyplot para crear gráficos básicos como líneas, barras o histogramas, mientras que seaborn facilita la generación de gráficos estadísticos más avanzados y estéticos, como mapas de calor o diagramas de caja.
#
# Para el caso de  coordenadas geográficas, folium es útil para construir mapas interactivos que permiten representar datos espaciales. En cuanto a la preparación y modelado con machine learning, train_test_split de sklearn divide los datos en conjuntos de entrenamiento y prueba, lo que es esencial para validar modelos. StandardScaler se encarga de normalizar variables numéricas, LabelEncoder convierte variables categóricas en valores numéricos, y SimpleImputer permite imputar valores faltantes con distintas estrategias.
#
# Finalmente, LinearRegression implementa un modelo de regresión lineal que se utiliza para predecir valores continuos. Para evaluar su rendimiento, se aplican métricas como el error cuadrático medio (mean_squared_error) y el coeficiente de determinación (r2_score), que indican la precisión del modelo al predecir los datos.

# %% [markdown]
# **Zona de Estudio con GEE**

# %% [markdown]
# Utiliza imagenes Sentinel-2 corregido atmosféricamente (COPERNICUS/S2_SR).
#
# Filtra imágenes con menos del 20% de nubes
#
# Selecciona la estacion por año (primavera e invierno)
#
# Primero se debe habilitar una APi de GEE version gratuita, luego se procede a armar un proyecto o carpeta en GEE y se habilita para despues seguir con el codigo en Colab

# %%
# Instalar y cargar Earth Engine
# !pip install earthengine-api folium geemap --quiet

import ee
ee.Authenticate()  # ← Esto abre un enlace para autorizar tu cuenta
ee.Initialize(project='mentorias-463215')  # Solo después de autenticar
ee.Initialize(project='mentorias-463215')  # Reemplazado con mi ID de proyecto

# Punto central: Franja costera del Río de La Plata
punto = ee.Geometry.Point([-58.4464023, -34.5375533])
zona = punto.buffer(1000).bounds()

# Función para obtener una imagen limpia por estación y año
def obtener_imagen(estacion, fecha_ini, fecha_fin):
    coleccion = ee.ImageCollection('COPERNICUS/S2_SR') \
        .filterBounds(zona) \
        .filterDate(fecha_ini, fecha_fin) \
        .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 20)) \
        .sort('CLOUDY_PIXEL_PERCENTAGE') \
        .first() \
        .clip(zona)

    vis_params = {'min': 0, 'max': 3000, 'bands': ['B4', 'B3', 'B2']}  # RGB
    return coleccion.visualize(**vis_params).set({'title': estacion})

# Crear diccionario con las estaciones
imagenes = {
    'Invierno 2021': obtener_imagen('Invierno 2021', '2021-06-21', '2021-09-21'),
    'Primavera 2021': obtener_imagen('Primavera 2021', '2021-09-22', '2021-12-20'),
    'Invierno 2022': obtener_imagen('Invierno 2022', '2022-06-21', '2022-09-21'),
    'Primavera 2022': obtener_imagen('Primavera 2022', '2022-09-22', '2022-12-20'),
}

# Crear mapa
m = geemap.Map(center=[-34.5375533, -58.4464023], zoom=13)

# Agregar capas al mapa
for nombre, imagen in imagenes.items():
    m.addLayer(imagen, {}, nombre)

m.add_legend(title="Estaciones", labels=list(imagenes.keys()), colors=['#999999']*4)
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# /usr/local/lib/python3.11/dist-packages/ee/deprecation.py:207: DeprecationWarning:
#
# Attention required for COPERNICUS/S2_SR! You are using a deprecated asset.
# To make sure your code keeps working, please update it.
# Learn more: https://developers.google.com/earth-engine/datasets/catalog/COPERNICUS_S2_SR
#
#   warnings.warn(warning, category=DeprecationWarning)
# Map(center=[-34.5375533, -58.4464023], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=…

# %% [markdown]
# Las imágenes satelitales correspondientes a invierno y primavera de los años 2021 y 2022 permiten evidenciar condiciones ambientales superficiales en distintas estaciones y años. Las variaciones en la coloración del agua observadas en las escenas pueden reflejar diferencias en la turbidez, en la presencia de sedimentos en suspensión o incluso en posibles floraciones algales, todos ellos considerados indicadores indirectos del estado de la calidad del agua. Además, el contraste entre áreas ribereñas vegetadas y zonas construidas permite inferir el grado de permeabilidad del entorno y su influencia en los procesos de escurrimiento y arrastre de contaminantes hacia el río.
#
# Estas imágenes también permiten interpretar procesos ambientales que afectan directamente la calidad del agua. Por ejemplo, un aumento del verdor costero durante la primavera podría asociarse a una mayor actividad agrícola o a un incremento en la escorrentía de fertilizantes, mientras que la presencia de tonalidades marrones u opacas en el cuerpo de agua puede estar relacionada con una mayor carga de sedimentos o materia orgánica en suspensión, resultado de fenómenos como la erosión del suelo, precipitaciones intensas o vertidos cloacales.
#
# Finalmente, la comparación entre años permite detectar patrones interanuales. Si en una misma estación se observa una mayor degradación visual del agua en un año respecto a otro, es posible vincular esa diferencia con condiciones climáticas particulares (como sequías o lluvias extremas) o con transformaciones en el uso del suelo del entorno inmediato al cauce.

# %% [markdown]
# **Descripcion del dataset**

# %% [markdown]
# Al analizar el dataset Conexiones_Transparentes.csv, se observó primero su dimensión general, es decir, cuántas filas y columnas contiene.Se identificó  613 registros distribuidos en 45 columnas. Esto permitió tener una idea inicial del volumen de datos con los que se va a trabajar. Luego, se revisaron los tipos de datos de cada variable, lo cual permite entender si se trata de valores numéricos, texto, fechas u otro tipo de información, y así anticipar qué tipo de análisis será necesario en cada caso.
#
# Finalmente, se visualizaron las primeras filas del dataset, lo que sirvió para conocer cómo están estructurados los datos, si los nombres de las columnas son claros, si hay valores atípicos o mal cargados a simple vista, y empezar a identificar patrones o variables relevantes.

# %%
# Configuracion de pandas

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Cargar el dataset

url = "https://raw.githubusercontent.com/MaricelSantos/Mentoria--Diplodatos-2025/main/Conexiones_Transparentes.csv"
df = pd.read_csv(url)

# Descripcion del dataset
print("Dimensiones del dataset:")
print(df.shape)

print("\nTipos de datos:")
print(df.dtypes)

print("\nPrimeras filas del dataset:")
display(df.head())
# Out:
# Dimensiones del dataset:
# (613, 45)
#
# Tipos de datos:
# orden                                                                               float64
# sitios                                                                               object
# codigo                                                                               object
# fecha                                                                                object
# año                                                                                  object
# campaña                                                                              object
# tem_agua                                                                             object
# tem_aire                                                                             object
# od                                                                                   object
# ph                                                                                   object
# olores                                                                               object
# color                                                                                object
# espumas                                                                              object
# mat_susp                                                                             object
# colif_fecales_ufc_100ml                                                              object
# escher_coli_ufc_100ml                                                                object
# enteroc_ufc_100ml                                                                    object
# nitrato_mg_l                                                                         object
# nh4_mg_l                                                                             object
# p_total_l_mg_l                                                                       object
# fosf_ortofos_mg_l                                                                    object
# dbo_mg_l                                                                             object
# dqo_mg_l                                                                             object
# turbiedad_ntu                                                                        object
# hidr_deriv_petr_ug_l                                                                 object
# cr_total_mg_l                                                                        object
# cd_total_mg_l                                                                        object
# clorofila_a_ug_l                                                                     object
# microcistina_ug_l                                                                    object
# ica                                                                                  object
# calidad_de_agua                                                                      object
# gobierno_local                                                                       object
# sitio                                                                                object
# latitud                                                                              object
# longitud                                                                             object
# Poblacion_partido                                                                    object
# Personas_con_cloacas                                                                 object
# Actividad_principal                                                                  object
# Agricultura, ganadería, caza y silvicultura                                         float64
# Pesca explotación de criaderos de peces y granjas piscícolas y servicios conexos    float64
# Explotación de minas y canteras                                                     float64
# Industria Manufacturera                                                             float64
# Electricidad, gas y agua                                                            float64
# Construcción                                                                        float64
# Servicios                                                                           float64
# dtype: object
#
# Primeras filas del dataset:
#    orden                      sitios codigo       fecha     año    campaña  \
# 0   23.0  Polo Petroquímico Dock Sud  AV051   24/2/2021  2021.0     verano
# 1   23.0  Polo Petroquímico Dock Sud  AV051   19/5/2021  2021.0      otoño
# 2   23.0  Polo Petroquímico Dock Sud  AV051   25/8/2021  2021.0   invierno
# 3   23.0  Polo Petroquímico Dock Sud  AV051  27/10/2021  2021.0  primavera
# 4   24.0              Arroyo Sarandí  AV052   24/2/2021  2021.0     verano
#
#   tem_agua     tem_aire    od    ph     olores      color    espumas  \
# 0     25.3  no se midió  4.77  6.61   Ausencia   Ausencia   Ausencia
# 1     16.2         14.5  5.95  7.79   Ausencia   Ausencia   Ausencia
# 2     15.1         12.8  3.76  7.11  Ausencia   Ausencia   Ausencia
# 3     23.9           28  4.59  6.76   Ausencia   Ausencia   Ausencia
# 4     25.5  no se midió  3.22  6.87   Ausencia   Ausencia   Ausencia
#
#     mat_susp colif_fecales_ufc_100ml escher_coli_ufc_100ml enteroc_ufc_100ml  \
# 0   Ausencia                    2000                  1320               450
# 1   Ausencia                    5000                  2400                60
# 2  Ausencia                    40000                  3000                20
# 3   Ausencia                    2000                   100               100
# 4   Ausencia                   10000                  3200               600
#
#   nitrato_mg_l nh4_mg_l p_total_l_mg_l fosf_ortofos_mg_l dbo_mg_l dqo_mg_l  \
# 0          4.3     0.36              1              0.44     <2.0      <30
# 1          3.6      3.3           0.33              0.33        6      5.2
# 2          2.2        2           0.61              0.56      3.3      <30
# 3         <2.0      1.5           0.25              0.29      2.4       52
# 4            4      1.6           0.98              0.46      6.4      <30
#
#   turbiedad_ntu hidr_deriv_petr_ug_l cr_total_mg_l cd_total_mg_l  \
# 0            45                 <100          <5.0        <0.001
# 1           <30                   80          <100        <0.005
# 2            13                 <100        <0.005        <0.001
# 3            15                 <100        <0.005        <0.001
# 4            32                 <100          <5.0        <0.001
#
#   clorofila_a_ug_l microcistina_ug_l ica             calidad_de_agua  \
# 0                0             <0.15  45             Muy deteriorada
# 1           <0.001           <10.000  48             Muy deteriorada
# 2           <0.010             <0.20  40  Extremadamente deteriorada
# 3            <0.01             <0.20  52             Muy deteriorada
# 4            0.005             <0.15  39  Extremadamente deteriorada
#
#   gobierno_local sitio latitud longitud Poblacion_partido  \
# 0            NaN   NaN     NaN      NaN               NaN
# 1            NaN   NaN     NaN      NaN               NaN
# 2            NaN   NaN     NaN      NaN               NaN
# 3            NaN   NaN     NaN      NaN               NaN
# 4            NaN   NaN     NaN      NaN               NaN
#
#   Personas_con_cloacas Actividad_principal  \
# 0                  NaN                 NaN
# 1                  NaN                 NaN
# 2                  NaN                 NaN
# 3                  NaN                 NaN
# 4                  NaN                 NaN
#
#    Agricultura, ganadería, caza y silvicultura  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    Pesca explotación de criaderos de peces y granjas piscícolas y servicios conexos  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Explotación de minas y canteras  Industria Manufacturera  \
# 0                              NaN                      NaN
# 1                              NaN                      NaN
# 2                              NaN                      NaN
# 3                              NaN                      NaN
# 4                              NaN                      NaN
#
#    Electricidad, gas y agua  Construcción  Servicios
# 0                       NaN           NaN        NaN
# 1                       NaN           NaN        NaN
# 2                       NaN           NaN        NaN
# 3                       NaN           NaN        NaN
# 4                       NaN           NaN        NaN

# %% [markdown]
# Al revisar los tipos de datos, la mayoría de las columnas están clasificadas como objetos (object), lo que indica que contienen datos categóricos o texto.

# %% [markdown]
# **Analisis exploratorio**

# %% [markdown]
# La información general del dataset muestra un total de 613 registros distribuidos en 45 columnas. Sin embargo, no todas las columnas tienen la misma cantidad de datos completos. Algunas presentan valores faltantes, como es el caso de tem_aire , lo que indica que ciertas observaciones no fueron medidas o registradas en todas las campañas o estaciones.
#
# Además, se nota que la mayoría de las columnas están tipadas como object, incluso aquellas que deberían contener valores numéricos, como od, nitrato_mg_l, entre otras. Esto sugiere que probablemente haya que hacer una conversión de tipos para poder analizarlas correctamente, ya sea por el uso de comas como separadores decimales o por la presencia de caracteres no numéricos.
#
# Esta revisión general  permite detectar desde el inicio qué variables requieren limpieza o transformación antes de cualquier análisis o modelado más avanzado. También da una idea del nivel de completitud de los datos y de los posibles desafíos que habrá que enfrentar en el preprocesamiento.

# %%
# Informacion general
print("\nInformación general:")
df.info()
# Out:
# Información general:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 613 entries, 0 to 612
# Data columns (total 45 columns):
#  #   Column                                                                            Non-Null Count  Dtype
# ---  ------                                                                            --------------  -----
#  0   orden                                                                             589 non-null    float64
#  1   sitios                                                                            589 non-null    object
#  2   codigo                                                                            613 non-null    object
#  3   fecha                                                                             589 non-null    object
#  4   año                                                                               573 non-null    object
#  5   campaña                                                                           573 non-null    object
#  6   tem_agua                                                                          572 non-null    object
#  7   tem_aire                                                                          561 non-null    object
#  8   od                                                                                572 non-null    object
#  9   ph                                                                                567 non-null    object
#  10  olores                                                                            574 non-null    object
#  11  color                                                                             574 non-null    object
#  12  espumas                                                                           574 non-null    object
#  13  mat_susp                                                                          574 non-null    object
#  14  colif_fecales_ufc_100ml                                                           571 non-null    object
#  15  escher_coli_ufc_100ml                                                             573 non-null    object
#  16  enteroc_ufc_100ml                                                                 573 non-null    object
#  17  nitrato_mg_l                                                                      573 non-null    object
#  18  nh4_mg_l                                                                          573 non-null    object
#  19  p_total_l_mg_l                                                                    572 non-null    object
#  20  fosf_ortofos_mg_l                                                                 573 non-null    object
#  21  dbo_mg_l                                                                          571 non-null    object
#  22  dqo_mg_l                                                                          574 non-null    object
#  23  turbiedad_ntu                                                                     574 non-null    object
#  24  hidr_deriv_petr_ug_l                                                              574 non-null    object
#  25  cr_total_mg_l                                                                     573 non-null    object
#  26  cd_total_mg_l                                                                     574 non-null    object
#  27  clorofila_a_ug_l                                                                  572 non-null    object
#  28  microcistina_ug_l                                                                 573 non-null    object
#  29  ica                                                                               560 non-null    object
#  30  calidad_de_agua                                                                   544 non-null    object
#  31  gobierno_local                                                                    290 non-null    object
#  32  sitio                                                                             290 non-null    object
#  33  latitud                                                                           290 non-null    object
#  34  longitud                                                                          290 non-null    object
#  35  Poblacion_partido                                                                 290 non-null    object
#  36  Personas_con_cloacas                                                              290 non-null    object
#  37  Actividad_principal                                                               290 non-null    object
#  38  Agricultura, ganadería, caza y silvicultura                                       168 non-null    float64
#  39  Pesca explotación de criaderos de peces y granjas piscícolas y servicios conexos  168 non-null    float64
#  40  Explotación de minas y canteras                                                   168 non-null    float64
#  41  Industria Manufacturera                                                           168 non-null    float64
#  42  Electricidad, gas y agua                                                          168 non-null    float64
#  43  Construcción                                                                      168 non-null    float64
#  44  Servicios                                                                         168 non-null    float64
# dtypes: float64(8), object(37)
# memory usage: 215.6+ KB

# %% [markdown]
# En la tabla cada fila representa una columna del DataFrame. Esto significa lo siguiente:
#
# Column: el nombre de la columna, por ejemplo, orden, sitios, codigo, etc.
#
# Non-Null Count: cantidad de valores que no están vacíos (no son NaN) en esa columna. Por ejemplo, orden tiene 589 valores no nulos, lo que implica que 24 filas tienen datos faltantes en esa columna (613 - 589 = 24).
#
# Dtype: el tipo de dato que tiene esa columna:
#
# - float64: números decimales.
# - object: generalmente texto o una mezcla de tipos (podrían ser números como texto, fechas mal interpretadas, etc.).

# %% [markdown]
# **Procesamiento de datos**

# %% [markdown]
# Indica cuántos registros están completamente duplicados, es decir, que repiten todos los valores en todas sus columnas. Este paso permite asegurarse de que no haya información repetida que pueda sesgar los análisis o inflar resultados sin aportar datos nuevos. Saber si existen duplicados también ayuda a decidir si es necesario limpiar el dataset antes de seguir trabajando.

# %%
# Datos duplicados
print("\nCantidad de datos duplicados:")
print(df.duplicated().sum())
# Out:
# Cantidad de datos duplicados:
# 18

# %% [markdown]
# **Identificacion de datos duplicados**

# %% [markdown]
# Este analisis permite identificar si existen registros exactamente repetidos dentro del dataset. Primero se confirmó cuántas filas completas están duplicadas, lo que indica que ciertos registros fueron cargados más de una vez sin ningún cambio en ninguna de sus columnas. Estas filas duplicadas fueron mostradas en una tabla para poder inspeccionarlas visualmente y decidir si conviene eliminarlas en el preprocesamiento.
#
# Luego se revisó cada columna por separado para detectar si contiene valores repetidos, aunque no necesariamente en filas idénticas. Esto ayuda a identificar, por ejemplo, si hay valores que se repiten demasiado en campos que deberían ser únicos (como una estación de monitoreo o una fecha) o si hay agrupamientos naturales que podrían aprovecharse durante el análisis.

# %%
# Filas duplicadas
print("\nCantidad de filas duplicadas:")
print(df.duplicated().sum())

print("\nFilas duplicadas:")
duplicadas = df[df.duplicated()]
display(duplicadas)

# Valores duplicados de cada columna
print("\nColumnas con valores duplicados:")
for col in df.columns:
    valores_duplicados = df[col][df[col].duplicated()].unique()
    if len(valores_duplicados) > 0:
        print(f"\nColumna: {col}")
        print(f"Valores duplicados: {valores_duplicados}")
# Out:
# Cantidad de filas duplicadas:
# 18
#
# Filas duplicadas:
#      orden sitios   codigo fecha  año campaña tem_agua tem_aire   od   ph  \
# 224    NaN    NaN  CA CU01   NaN  NaN     NaN      NaN      NaN  NaN  NaN
# 225    NaN    NaN  CA CU02   NaN  NaN     NaN      NaN      NaN  NaN  NaN
# 226    NaN    NaN  CA CU03   NaN  NaN     NaN      NaN      NaN  NaN  NaN
# 227    NaN    NaN  CA CU04   NaN  NaN     NaN      NaN      NaN  NaN  NaN
# 228    NaN    NaN  CA CU05   NaN  NaN     NaN      NaN      NaN  NaN  NaN
# 245    NaN    NaN    EN AD   NaN  NaN     NaN      NaN      NaN  NaN  NaN
# 399    NaN    NaN  CA CU01   NaN  NaN     NaN      NaN      NaN  NaN  NaN
# 400    NaN    NaN  CA CU02   NaN  NaN     NaN      NaN      NaN  NaN  NaN
# 401    NaN    NaN  CA CU03   NaN  NaN     NaN      NaN      NaN  NaN  NaN
# 402    NaN    NaN  CA CU04   NaN  NaN     NaN      NaN      NaN  NaN  NaN
# 403    NaN    NaN  CA CU05   NaN  NaN     NaN      NaN      NaN  NaN  NaN
# 420    NaN    NaN    EN AD   NaN  NaN     NaN      NaN      NaN  NaN  NaN
# 549    NaN    NaN  CA CU01   NaN  NaN     NaN      NaN      NaN  NaN  NaN
# 550    NaN    NaN  CA CU02   NaN  NaN     NaN      NaN      NaN  NaN  NaN
# 551    NaN    NaN  CA CU03   NaN  NaN     NaN      NaN      NaN  NaN  NaN
# 552    NaN    NaN  CA CU04   NaN  NaN     NaN      NaN      NaN  NaN  NaN
# 553    NaN    NaN  CA CU05   NaN  NaN     NaN      NaN      NaN  NaN  NaN
# 562    NaN    NaN    EN AD   NaN  NaN     NaN      NaN      NaN  NaN  NaN
#
#     olores color espumas mat_susp colif_fecales_ufc_100ml  \
# 224    NaN   NaN     NaN      NaN                     NaN
# 225    NaN   NaN     NaN      NaN                     NaN
# 226    NaN   NaN     NaN      NaN                     NaN
# 227    NaN   NaN     NaN      NaN                     NaN
# 228    NaN   NaN     NaN      NaN                     NaN
# 245    NaN   NaN     NaN      NaN                     NaN
# 399    NaN   NaN     NaN      NaN                     NaN
# 400    NaN   NaN     NaN      NaN                     NaN
# 401    NaN   NaN     NaN      NaN                     NaN
# 402    NaN   NaN     NaN      NaN                     NaN
# 403    NaN   NaN     NaN      NaN                     NaN
# 420    NaN   NaN     NaN      NaN                     NaN
# 549    NaN   NaN     NaN      NaN                     NaN
# 550    NaN   NaN     NaN      NaN                     NaN
# 551    NaN   NaN     NaN      NaN                     NaN
# 552    NaN   NaN     NaN      NaN                     NaN
# 553    NaN   NaN     NaN      NaN                     NaN
# 562    NaN   NaN     NaN      NaN                     NaN
#
#     escher_coli_ufc_100ml enteroc_ufc_100ml nitrato_mg_l nh4_mg_l  \
# 224                   NaN               NaN          NaN      NaN
# 225                   NaN               NaN          NaN      NaN
# 226                   NaN               NaN          NaN      NaN
# 227                   NaN               NaN          NaN      NaN
# 228                   NaN               NaN          NaN      NaN
# 245                   NaN               NaN          NaN      NaN
# 399                   NaN               NaN          NaN      NaN
# 400                   NaN               NaN          NaN      NaN
# 401                   NaN               NaN          NaN      NaN
# 402                   NaN               NaN          NaN      NaN
# 403                   NaN               NaN          NaN      NaN
# 420                   NaN               NaN          NaN      NaN
# 549                   NaN               NaN          NaN      NaN
# 550                   NaN               NaN          NaN      NaN
# 551                   NaN               NaN          NaN      NaN
# 552                   NaN               NaN          NaN      NaN
# 553                   NaN               NaN          NaN      NaN
# 562                   NaN               NaN          NaN      NaN
#
#     p_total_l_mg_l fosf_ortofos_mg_l dbo_mg_l dqo_mg_l turbiedad_ntu  \
# 224            NaN               NaN      NaN      NaN           NaN
# 225            NaN               NaN      NaN      NaN           NaN
# 226            NaN               NaN      NaN      NaN           NaN
# 227            NaN               NaN      NaN      NaN           NaN
# 228            NaN               NaN      NaN      NaN           NaN
# 245            NaN               NaN      NaN      NaN           NaN
# 399            NaN               NaN      NaN      NaN           NaN
# 400            NaN               NaN      NaN      NaN           NaN
# 401            NaN               NaN      NaN      NaN           NaN
# 402            NaN               NaN      NaN      NaN           NaN
# 403            NaN               NaN      NaN      NaN           NaN
# 420            NaN               NaN      NaN      NaN           NaN
# 549            NaN               NaN      NaN      NaN           NaN
# 550            NaN               NaN      NaN      NaN           NaN
# 551            NaN               NaN      NaN      NaN           NaN
# 552            NaN               NaN      NaN      NaN           NaN
# 553            NaN               NaN      NaN      NaN           NaN
# 562            NaN               NaN      NaN      NaN           NaN
#
#     hidr_deriv_petr_ug_l cr_total_mg_l cd_total_mg_l clorofila_a_ug_l  \
# 224                  NaN           NaN           NaN              NaN
# 225                  NaN           NaN           NaN              NaN
# 226                  NaN           NaN           NaN              NaN
# 227                  NaN           NaN           NaN              NaN
# 228                  NaN           NaN           NaN              NaN
# 245                  NaN           NaN           NaN              NaN
# 399                  NaN           NaN           NaN              NaN
# 400                  NaN           NaN           NaN              NaN
# 401                  NaN           NaN           NaN              NaN
# 402                  NaN           NaN           NaN              NaN
# 403                  NaN           NaN           NaN              NaN
# 420                  NaN           NaN           NaN              NaN
# 549                  NaN           NaN           NaN              NaN
# 550                  NaN           NaN           NaN              NaN
# 551                  NaN           NaN           NaN              NaN
# 552                  NaN           NaN           NaN              NaN
# 553                  NaN           NaN           NaN              NaN
# 562                  NaN           NaN           NaN              NaN
#
#     microcistina_ug_l  ica calidad_de_agua gobierno_local  \
# 224               NaN  NaN             NaN           CABA
# 225               NaN  NaN             NaN           CABA
# 226               NaN  NaN             NaN           CABA
# 227               NaN  NaN             NaN           CABA
# 228               NaN  NaN             NaN           CABA
# 245               NaN  NaN             NaN       Ensenada
# 399               NaN  NaN             NaN           CABA
# 400               NaN  NaN             NaN           CABA
# 401               NaN  NaN             NaN           CABA
# 402               NaN  NaN             NaN           CABA
# 403               NaN  NaN             NaN           CABA
# 420               NaN  NaN             NaN       Ensenada
# 549               NaN  NaN             NaN           CABA
# 550               NaN  NaN             NaN           CABA
# 551               NaN  NaN             NaN           CABA
# 552               NaN  NaN             NaN           CABA
# 553               NaN  NaN             NaN           CABA
# 562               NaN  NaN             NaN       Ensenada
#
#                                                  sitio      latitud  \
# 224  Reserva ecológica ciudad universitaria costane...  -34.535.878
# 225  Reserva ciudad universitaria: boca de entrada ...  -34.537.272
# 226  Reserva ciudad universitaria: marisma canal de...  -34.538.686
# 227  Reserva ciudad universitaria: humedal central ...  -34.539.667
# 228  Reserva ciudad universitaria: dique sur subsis...  -34.540.675
# 245          Boca cerrada (res. extra nat. punta Lara)  -34.781.253
# 399  Reserva ecológica ciudad universitaria costane...  -34.535.878
# 400  Reserva ciudad universitaria: boca de entrada ...  -34.537.272
# 401  Reserva ciudad universitaria: marisma canal de...  -34.538.686
# 402  Reserva ciudad universitaria: humedal central ...  -34.539.667
# 403  Reserva ciudad universitaria: dique sur subsis...  -34.540.675
# 420          Boca cerrada (res. extra nat. punta Lara)  -34.781.253
# 549  Reserva ecológica ciudad universitaria costane...  -34.535.878
# 550  Reserva ciudad universitaria: boca de entrada ...  -34.537.272
# 551  Reserva ciudad universitaria: marisma canal de...  -34.538.686
# 552  Reserva ciudad universitaria: humedal central ...  -34.539.667
# 553  Reserva ciudad universitaria: dique sur subsis...  -34.540.675
# 562          Boca cerrada (res. extra nat. punta Lara)  -34.781.253
#
#         longitud Poblacion_partido Personas_con_cloacas  \
# 224  -58.445.933         3.121.707            3.049.672
# 225  -58.448.339         3.121.707            3.049.672
# 226  -58.445.589         3.121.707            3.049.672
# 227  -58.443.781         3.121.707            3.049.672
# 228     -584.419         3.121.707            3.049.672
# 245  -58.008.481            63.997               37.375
# 399  -58.445.933         3.121.707            3.049.672
# 400  -58.448.339         3.121.707            3.049.672
# 401  -58.445.589         3.121.707            3.049.672
# 402  -58.443.781         3.121.707            3.049.672
# 403     -584.419         3.121.707            3.049.672
# 420  -58.008.481            63.997               37.375
# 549  -58.445.933         3.121.707            3.049.672
# 550  -58.448.339         3.121.707            3.049.672
# 551  -58.445.589         3.121.707            3.049.672
# 552  -58.443.781         3.121.707            3.049.672
# 553     -584.419         3.121.707            3.049.672
# 562  -58.008.481            63.997               37.375
#
#                                    Actividad_principal  \
# 224  "servicios inmobiliarios, financieros y comercio"
# 225  "servicios inmobiliarios, financieros y comercio"
# 226  "servicios inmobiliarios, financieros y comercio"
# 227  "servicios inmobiliarios, financieros y comercio"
# 228  "servicios inmobiliarios, financieros y comercio"
# 245              "siderúrgica y refineria de petroleo"
# 399  "servicios inmobiliarios, financieros y comercio"
# 400  "servicios inmobiliarios, financieros y comercio"
# 401  "servicios inmobiliarios, financieros y comercio"
# 402  "servicios inmobiliarios, financieros y comercio"
# 403  "servicios inmobiliarios, financieros y comercio"
# 420              "siderúrgica y refineria de petroleo"
# 549  "servicios inmobiliarios, financieros y comercio"
# 550  "servicios inmobiliarios, financieros y comercio"
# 551  "servicios inmobiliarios, financieros y comercio"
# 552  "servicios inmobiliarios, financieros y comercio"
# 553  "servicios inmobiliarios, financieros y comercio"
# 562              "siderúrgica y refineria de petroleo"
#
#      Agricultura, ganadería, caza y silvicultura  \
# 224                                          NaN
# 225                                          NaN
# 226                                          NaN
# 227                                          NaN
# 228                                          NaN
# 245                                          NaN
# 399                                          NaN
# 400                                          NaN
# 401                                          NaN
# 402                                          NaN
# 403                                          NaN
# 420                                          NaN
# 549                                          NaN
# 550                                          NaN
# 551                                          NaN
# 552                                          NaN
# 553                                          NaN
# 562                                          NaN
#
#      Pesca explotación de criaderos de peces y granjas piscícolas y servicios conexos  \
# 224                                                NaN
# 225                                                NaN
# 226                                                NaN
# 227                                                NaN
# 228                                                NaN
# 245                                                NaN
# 399                                                NaN
# 400                                                NaN
# 401                                                NaN
# 402                                                NaN
# 403                                                NaN
# 420                                                NaN
# 549                                                NaN
# 550                                                NaN
# 551                                                NaN
# 552                                                NaN
# 553                                                NaN
# 562                                                NaN
#
#      Explotación de minas y canteras  Industria Manufacturera  \
# 224                              NaN                      NaN
# 225                              NaN                      NaN
# 226                              NaN                      NaN
# 227                              NaN                      NaN
# 228                              NaN                      NaN
# 245                              NaN                      NaN
# 399                              NaN                      NaN
# 400                              NaN                      NaN
# 401                              NaN                      NaN
# 402                              NaN                      NaN
# 403                              NaN                      NaN
# 420                              NaN                      NaN
# 549                              NaN                      NaN
# 550                              NaN                      NaN
# 551                              NaN                      NaN
# 552                              NaN                      NaN
# 553                              NaN                      NaN
# 562                              NaN                      NaN
#
#      Electricidad, gas y agua  Construcción  Servicios
# 224                       NaN           NaN        NaN
# 225                       NaN           NaN        NaN
# 226                       NaN           NaN        NaN
# 227                       NaN           NaN        NaN
# 228                       NaN           NaN        NaN
# 245                       NaN           NaN        NaN
# 399                       NaN           NaN        NaN
# 400                       NaN           NaN        NaN
# 401                       NaN           NaN        NaN
# 402                       NaN           NaN        NaN
# 403                       NaN           NaN        NaN
# 420                       NaN           NaN        NaN
# 549                       NaN           NaN        NaN
# 550                       NaN           NaN        NaN
# 551                       NaN           NaN        NaN
# 552                       NaN           NaN        NaN
# 553                       NaN           NaN        NaN
# 562                       NaN           NaN        NaN
# Columnas con valores duplicados:
#
# Columna: orden
# Valores duplicados: [23. 24. 26. 22. 25. 39. 37. 41. 42. 40. 38. 31. 30. 32. nan 18. 19. 20.
#  21. 33. 34. 35. 36. 27. 28. 29. 10. 11. 12. 14. 13.  1.  3.  4.  5.  6.
#   2.  7.  8.  9. 17. 16. 15. 43.]
#
# Columna: sitios
# Valores duplicados: ['Polo Petroquímico Dock Sud' 'Arroyo Sarandí' 'Arroyo Santo Domingo'
#  'Escollera de Propaneros' 'Costa de Villa Domínico     '
#  'Playa La Bagliardi' 'Balneario Palo Blanco' 'Playa La Balandra'
#  'Balneario Municipal' 'Diagonal 66 (descarga cloaca)'
#  'Puerto Trinidad calle 47' 'Calle 14 y Costa - Salida cloaca'
#  'Costanera Hudson Calle 63' nan 'Parque de los Niños'
#  'Costanera Norte - Espigón Abanico' 'Club de Pescadores'
#  'Reserva Ecológica Costanera Sur - Playita' 'Camping Eva Perón'
#  'Toma de agua Club de Pesca' 'Arroyo El Gato'
#  'Ensenada Prefectura Isla Santiago' 'Espora 400 m' 'Náutico 400 m'
#  'Pejerrey Club 400 m' 'Del Arca' 'Espigón La Farola' 'Reserva Ecológica'
#  'Perú Puente' 'Playa Espigón de Pacheco' 'Canal Villanueva y Río Luján'
#  'Canal Aliviador y Río Lujan' 'Río Carapachay y Arroyo Gallo Fiambre'
#  'Río Reconquista y Río Lujan' 'Rio Tigre 100m antes del Rio Luján'
#  'Río Lujan y Arroyo Caraguatá' 'Río Lujan y Canal San Fernando'
#  'Río Capitán y Río San Antonio' 'Arroyo Abra Vieja y Santa Rosa'
#  'Costa y Melo' 'Puerto de Olivos Espigón' 'Reserva Barrio El Ceibo '
#  'Costa de Villa Domínico' 'Boca Cerrada (Res.Nat. Punta Lara)'
#  'Reserva Barrio El Ceibo' 'Cuatro bocas- desembocadura del Riachuelo']
#
# Columna: codigo
# Valores duplicados: ['AV051' 'AV052' 'AV053' 'AV054' 'AV055' 'BS091' 'BS092' 'BS093' 'BS094'
#  'BS095' 'BZ077' 'BZ078' 'BZ080' 'CA041' 'CA044' 'CA046' 'CA047' 'EN081'
#  'EN082' 'EN083' 'EN084' 'QU061' 'QU062' 'QU063' 'SF015' 'SI021' 'SI022'
#  'SI023' 'SI024' 'TI001' 'TI002' 'TI003' 'TI004' 'TI005' 'TI006' 'TI007'
#  'TI008' 'TI009' 'VL031' 'VL032' 'VL033' 'CA CU01' 'CA CU02' 'CA CU03'
#  'CA CU04' 'CA CU05' 'EN AD' 'EN-extra' 'EN-adic' 'AC001']
#
# Columna: fecha
# Valores duplicados: ['24/2/2021' '19/5/2021' '25/8/2021' '27/10/2021' nan '23/2/2022'
#  '4/5/2022' '23/8/2022' '31/10/2022' 'no midieron este día' '31/10/0202'
#  '23/8/2023' '22/2/2023' '10/5/2023' '14/11/2023' '8/4/2024' '45623'
#  '45628' 'no se muestreó']
#
# Columna: año
# Valores duplicados: ['2021.0' nan '2022' 'no midieron este día' '2023.0' '2024.0']
#
# Columna: campaña
# Valores duplicados: ['verano' 'otoño' 'invierno' 'primavera' nan 'Verano' 'Primavera'
#  'no midieron este día']
#
# Columna: tem_agua
# Valores duplicados: ['16.2' '26.1' '21.4' '16.7' 'no se midió' '10' '20' '7' '11' '21' '25.5'
#  '13' '26' '12' nan '24.9' '14.7' '23.8' '24.7' '14.5' '12.9' '23.5' '22'
#  '16' '25' '18' '27' '15' '25.6' '14.8' '15.7' '24.6' '24' '15.1' '14.4'
#  '24.5' '15.3' '24.2' '15.2' '14.6' '24.8' '14' '22.4' '25.7' '13.8'
#  '25.8' '17.8' '25.1' '17' '18.5' '8' '23' '25.4' 'no midieron este día'
#  '16.4' '13.6' '12.8' '23.9' '15.6' '17.1' '14.2' '14.3' '26.5' '18.4'
#  '21.5' '18.6' '20.4' '25.2' '18.2' '12.7' '13.5' '17.4' '18.3' '23.4'
#  '13.1' '16.1' '19' 'inaccesible' 'sin equipo' 'no muestreó' '27.8'
#  'no se muestreó' '24.4' '25.3' 'en obra' '28' '17.5' '13.7' '16.3' '15.5'
#  '15.8' '25.9' 's/i' '22.6']
#
# Columna: tem_aire
# Valores duplicados: ['no se midió' '14.5' '12.8' '29.1' '28' '19' '26' '27' '12' '16' '10' nan
#  '27.5' '20' '4' '11' '18' '7' '17' '32' '13' '14' '29' '24' '31' '22' '8'
#  '9' '24.2' '13.8' '25.2' '22.2' '15' 'no midieron este día' '25' '23'
#  '19.0' '23.3' '21' '15.1' 'inaccesible' 'no muestreó' 'no se muestreó'
#  'sin equipo' 'en obra' '11.3' '18.0' 's/i' '23.0' '20.0']
#
# Columna: od
# Valores duplicados: ['3.76' '4.24' 'no se midió' nan '4.7' '8.6' '12.47' '8.7' '7.58' '5.95'
#  '4.84' '6.4' '3.6' '3.91' '4.82' '6.9' '8.63' '8.2' '6.2' '4.07' '4.28'
#  '9.29' '5.36' '7.51' '5.07' 'no midio la sonda' 'No se midió' '6.99'
#  '7.2' '10.01' '11.82' '7.8' '7' 'no midieron este día' '8.9' '9' '7.17'
#  '8.57' '8.14' '5.7' '5.83' '5.3' '5.79' '7.85' '7.21' '8.83' '5.24' '6.3'
#  '3.22' '10.88' '6.24' '6.33' '5.8' 'inaccesible' 'sin equipo'
#  'no muestreó' '8' 'no se muestreó' '7.9' '7.60' '9.05' '8.28' 'N/R'
#  '5.85' '5.4' 'en obra' '6.5' '6.32' '5.61' '6.59' '8.53' '5.97' '4.31'
#  '5.02' '4.13' '5.94' '6.7' '2.94' '5.14' '4.88' '8.27' '4.9' '1.1' '0.5'
#  '1.6' '0.3' '8.4' '7.3' '9.1' '8.16' 's/i' '6.6' '8.5' '4.85' '6.14'
#  '4.05' '0.8' '4.67' '6.43' '1.5']
#
# Columna: ph
# Valores duplicados: ['7.21' 'no se midió' '7.79' '7.71' nan '7.6' '7.7' '7.4' '8.1' '9.18'
#  '8.95' '9.44' '8.04' '7.36' '7.47' '7.43' '7.69' '8.01' '7.67' '7.42'
#  '6.96' '7.04' '6.82' '7.05' '6.79' '6.75' '7.11' '6.8' '6.76' '6.71'
#  '6.92' '6.85' '7.59' '7.5' '7.81' '7.58' '7.48' '7.55' '7.3' '7.75'
#  '8.11' '7.99' '8.13' '7.93' 'no midieron este día' '7.8' '8.14' '7.76'
#  '7.52' '8,05' '7.12' '7.29' '6.66' '6.9' '7' '7.03' '7.06' '7.14' '7,67'
#  '6.94' '7.09' '6.88' '6.56' '7,58' '6.74' '7,57' '8,02' '7.32' '7.13'
#  '7.23' '7.39' '7.08' '7.45' '7.34' '7.84' '7.65' '8.09' '8.21' '7.96'
#  '9.39' 'inaccesible' '8.02' 'sin equipo' 'no muestreó' 'no se muestreó'
#  '7.30' '7.82' '7.66' '7.41' '6.91' '6.97' 'en obra' 'no funcionó' '-'
#  '7.24' '7.27' '7.33' '7.19' '7.17' '7.22' '6.49' '7.16' '7.07' '6.61'
#  '6.50' '6.53' '7.57' '8.08' '8.5' '8.7' '8.6' 's/i' '7.87' '8.2' '6.86'
#  '8.0' '6.81' '6.89' '6.7' '7.02']
#
# Columna: olores
# Valores duplicados: ['Ausencia' 'Ausencia ' 'no se midió' 'Presencia' nan 'Ausente'
#  'no midieron este día' 'ausencia' 'inaccesible' 'no muestreó'
#  'no se muestreó' 'en obra' 'presencia' 's/i']
#
# Columna: color
# Valores duplicados: ['Ausencia' 'Ausencia ' 'Presencia' 'no se midió' nan 'Ausente'
#  'no midieron este día' 'ausencia' 'inaccesible' 'no muestreó'
#  'no se muestreó' 'en obra' 's/i']
#
# Columna: espumas
# Valores duplicados: ['Ausencia' 'Ausencia ' 'no se midió' 'Presencia' nan 'Ausente'
#  'no midieron este día' 'ausencia' 'inaccesible' 'no muestreó'
#  'no se muestreó' 'en obra' 's/i']
#
# Columna: mat_susp
# Valores duplicados: ['Ausencia' 'Ausencia ' 'Presencia' 'no se midió' nan 'Ausente'
#  'no midieron este día' 'ausencia' 'inaccesible' 'no muestreó'
#  'no se muestreó' 'en obra' 'presencia' 's/i']
#
# Columna: colif_fecales_ufc_100ml
# Valores duplicados: ['2000' '40000' '9000' '1000' '10000' 'no se midió' '400' '80000' '3000'
#  '6000' '5000' nan '25000' '4000' '100000' '300' '1800' '12000' '15000'
#  '20000' '30000' '14000' '8000' '2500' '3800' '1300' '120000' '700' '1400'
#  '50000' '800' '600' '70000' '1600' '900' 'no midieron este día' '1200'
#  '500' '27000' '2200' '90000' '3500' '28000' '6500' '160' '60000' '1100'
#  '2400' '150000' '3200' '4200' '170000' '13000' 'sin muestra' '7000'
#  '19000' '200' '32000' 'inaccesible' 'no muestreó' '1.000' '18000'
#  'no se muestreó' '100' '2.000' 'en obra' '1700' '24.000' '5200' '23000'
#  '11000' '22000' '7600' '2100' 'no se analizó' '1500' '180000' 's/i'
#  '62000' '5300']
#
# Columna: escher_coli_ufc_100ml
# Valores duplicados: ['3000' '1000' '100' '200' '1500' 'no se midió' '20' '5000' '500' nan
#  '6000' '3800' '400' '2800' '50' '2500' '2000' '2400' '12000' '300'
#  '10000' '20000' '1400' '360' '7000' '600' '5' '800' '6' '230' '440'
#  '3600' '290' '330' '1600' '700' '30' 'no midieron este día' '50000' '3'
#  '80' '150' '110' '4200' '5200' '4500' '2100' '8000' '2' '6600' '4000'
#  '2200' 'sin muestra' '900' '1100' '3200' 'inaccesible' '130'
#  'no muestreó' '1300' 'no se muestreó' '850' '60' '35' '120' '170'
#  'en obra' '2300' '19000' '18000' '4100' '4400' '350' '11000' '1200'
#  '14000' '16000' 'no se analizó' '9000' 's/i' '2700' '48000' '380' '13000'
#  '5800' '220']
#
# Columna: enteroc_ufc_100ml
# Valores duplicados: ['600' '100' '800' '300' 'no se midió' '20' '240' '480' '500' '185' nan
#  '40' '370' '30' '10' '90' '5' '180' '1300' '450' '50' '2100' '200' '4600'
#  '2000' '150' '360' '140' '350' '660' '1100' '380' '400' '190' '260'
#  '28000' '2' '1500' '80' '270' '960' 'no midieron este día' '850' '45' '4'
#  '160' '110' '130' '580' '27' '700' '640' '220' '250' '1700' '730' '570'
#  '120' 'sin muestra' '1000' '290' '1200' '280' '5000' '230' '330'
#  'inaccesible' 'no muestreó' '780' '760' 'no se muestreó' '1160' '60' '15'
#  '750' '5600' 'en obra' '1400' '770' '3000' '900' '560' '920' '1600' '550'
#  '320' '1.500' '3500' 'no se analizó' '410' '4000' 's/i' '170' '340'
#  '2300' '1800']
#
# Columna: nitrato_mg_l
# Valores duplicados: ['<2.0' '3.1' '2.2' 'no se midió' '3.9' '3.5' '3.3' '4' '5.9' '4.3' '4.1'
#  '3.4' nan '4.2' '3.6' '5.4' '7.5' '6.2' '4.4' '3.2' '5.1' '3.7' '2.3'
#  '4.6' '6.6' '7' '2.8' '6.5' '2.1' '2.9' '3' '5.2' '5.6' '5.7' '6.1' '4.9'
#  '6.9' '12.6' '6.4' '1.9' '2' '10' '5.8' '8.5' '12.2' '7.1'
#  'no midieron este día' '8.2' '11.5' '13.3' '4.7' '6.3' '13.2' '10.8'
#  '7.7' '2.6' '2.7' '11.3' '8.8' '2.5' '8' '8.6' '11.7' '9.9' '10.5'
#  'inaccesible' '5.3' '2.4' 'no muestreó' '4.20' '<44' 'no se muestreó'
#  '7.3' '4.5' '10.6' '8.9' '3.8' '6.20' '13.9' 'en obra' '12.7' '14.4'
#  '5.5' '5.30' '10.1' '<1.00' '8.4' 's/i' '7.4' '7.2' '1.4' '7.9' '7.6'
#  '8.3' '2.0' '5' '6.8' '1.8' '1.2']
#
# Columna: nh4_mg_l
# Valores duplicados: ['2.7' '1.5' '3.1' '2' 'no se midió' '1.8' '0.7' '0.1' nan '1.6' '0.3'
#  '0.2' '2.9' '0.8' '1.2' '1' '0.6' '1.7' '1.1' '0.82' '0.5' '0.4' '0.98'
#  '4.3' '3' '2.3' '<0.05' '4.5' '3.3' '2.5' '0.06' '0.16' '0.34' '0.44'
#  '2.1' '0.9' '0.97' '2.2' '4.1' '0.049' '1.3' '0.41' '5.4' '0.21' '0.11'
#  '0.18' '1.9' '0.66' '0.08' '0.45' 'no midieron este día' '0.77' '0.14'
#  '5.6' '0.15' '3.9' '0.74' '0.75' '5.7' '0.42' '23' '0.05' '1.4' '5' '22'
#  '0.83' '0.26' '9.3' '0.22' '0.49' '0.63' '3.2' '0.57' '0.09' '0.39'
#  '0.51' '0.33' 'inaccesible' 'no muestreó' '0.61' 'no se muestreó' '0.87'
#  '0.24' '0.07' '0.69' '0.30' '0.17' '11' '0.52' '0.23' '1.10' '0.76'
#  '0.59' '1.50' '<0.78' '0.62' '10' 'en obra' '2.90' '0.94' '0.13' '0.56'
#  '3.50' '4.00' '2.6' '3.8' '0.25' '0.72' '0.71' '0.60' '0.92' '0.89'
#  '1.90' '1.00' '0.93' '1.20' '3.5' '0.64' '1.0' '0.88' '0.99' '<0.01'
#  '0.36' 's/i' '0.78' '0.37' '0.95' '0.12']
#
# Columna: p_total_l_mg_l
# Valores duplicados: ['0.61' '0.25' '0.75' '0.77' 'no se midió' '1.1' '0.73' '0.33' '<0.20'
#  '0.22' '0.36' '0.82' nan '0.64' '0.08' '0.76' '0.1' '1' '0.28' '0.98'
#  '0.38' '0.57' '0.26' '0.27' '0.35' '0.31' '0.41' '0.56' '0.51' '0.47'
#  '0.2' '0.44' '0.21' '1.5' '0.55' '0.65' '0.48' '1.3' '0.43' '0.19' '0.59'
#  '1.6' '1.2' '0.32' '0.34' '0.45' '0.69' '0.52' '0.78' '0.85' '0.42' '1.4'
#  '0.24' '0.54' '0.29' '30.12' '0.62' '0.88' 'no midieron este día' '0.53'
#  '0.39' '0.23' '0.4' '0.63' '0.37' '0.49' '0.18' '0.86' '1.9' '0.17'
#  '<0.10' '0.13' '0.20' '1.40' '0.79' 'inaccesible' '0.74' 'no muestreó'
#  '0.12' 'no se muestreó' '0.72' '0.15' '0.3' '0.16' '0.68' '0.14' '0.30'
#  '0.95' 'en obra' '0.46' '0.58' '0.5' '0.11' '0.10' 'no se analizó' 's/i']
#
# Columna: fosf_ortofos_mg_l
# Valores duplicados: ['0.63' '0.48' 'no se midió' '0.11' '1.1' '0.44' '1.2' '1.5' '0.22' '0.25'
#  '0.59' nan '0.38' '0.33' '0.19' '0.27' '0.2' '0.42' '0.41' '0.23' '0.53'
#  '0.29' '0.51' '0.3' '0.34' '0.36' '0.37' '<0.10' '0.56' '0.5' '0.35'
#  '0.55' '0.57' '0.14' '0.39' '0.31' '<0.20' '0.43' '0.32' '0.26' '0.73'
#  '0.54' '0.52' '0.49' '0.24' '0.68' '1.3' '0.85' '1.4' '0.62' '0.28'
#  '0.58' '0.4' 'no midieron este día' '0.18' '0.17' '0.21' '0.15' '0.30'
#  '0.46' '0.40' '0.47' '0.20' '0.13' '0.86' '0.16' '0.10' '0.12' '0.69'
#  '0.65' 'sin muestra' 'inaccesible' 'no muestreó' 'no se muestreó' '0.1'
#  'en obra' '0.61' '0.60' 's/i' 'no se analizó']
#
# Columna: dbo_mg_l
# Valores duplicados: ['6' 'no se midió' '2.7' '3' '2.4' '4.2' nan '<5' '6.9' '3.1' '7.1' '<2.0'
#  '2.1' '5.2' '6.3' '3.9' '6.8' '5.8' '4' '7' '5.5' '4.8' '4.1' '13' '5'
#  '2.3' '6.5' '12' '3.7' '4.3' '7.3' '4.7' '2.2' '8.9' '4.9' '3.2' '14'
#  '2.5' '5.7' '4.6' '7.2' '11' 'no midieron este día' '9.4' '5.4' '7.4'
#  '10' '18' '1.9' '4.4' '6.2' '3.6' '3.5' '2.8' '5.6' '3.3' '2.6' '7.7'
#  '3.8' '8.4' '3.4' 'inaccesible' '17' 'no muestreó' 'no se muestreó' '4.5'
#  '5.3' '2.0' 'en obra' 'no se analizó' 's/i' '<2' '3.0' '2' '4.0']
#
# Columna: dqo_mg_l
# Valores duplicados: ['<30' '32' '73' 'no se midió' '37' '55' '125' '52' '50' '62' nan '<50'
#  '35' '41' '12' '57' '4.5' '31' '5.6' '43' '5.2' '<2.0' '34' '59' '4.3'
#  '65' '29' '47' '88' '82' '33' '39' '30' '48' 'no midieron este día' '72'
#  '64' '46' '80' '49' '36' '67' '42' '63' '58' '54' '70' '66' '77'
#  'inaccesible' 'no muestreó' '130' 'no se muestreó' '76' '61' '38' '40'
#  '90' 'en obra' '53' 's/i' 'no se analizó']
#
# Columna: turbiedad_ntu
# Valores duplicados: ['13' '<30' '21' '45' '34' '10' 'no se midió' '14' '75' '12' '16' '70'
#  '50' nan '32' '31' '40' '36' '23' '15' '29' '22' '30' '18' '11' '25' '27'
#  '17' '19' '33' '20' '28' '60' '37' '84' 'no midieron este día' '35' '85'
#  '90' '39' '55' '26' '24' '9.3' '65' '80' '6' '45.00' '32.00' '110'
#  'inaccesible' '95' '12.00' 'no muestreó' '120' 'no se muestreó' '40.00'
#  '20.00' '27.00' '38' '17.00' 'en obra' '23.00' '50.00' '8.7' '60.00'
#  '70.00' '14.00' '66' '56.2' 's/i' '5.3' '140' '63.1']
#
# Columna: hidr_deriv_petr_ug_l
# Valores duplicados: ['<100' 'no se midió' '75' '65' '80' nan '60' '50' '70' '110' '45' '<0.10'
#  '\xa0<0.10' 'no midieron este día' 'inaccesible' 'no muestreó'
#  'no se muestreó' 'en obra' 's/i']
#
# Columna: cr_total_mg_l
# Valores duplicados: ['<0.005' '<5.0' '<100' 'no se midió' '0.0057' nan '<10' '<0.01' '0.0052'
#  '7' '0.007' '0.0061' '5' 'no midieron este día' '0.005' '0.006' '6'
#  '0.011' '0.009' '0' '0.008' 'inaccesible' 'no muestreó' 'no se muestreó'
#  'en obra' '0.0051' 's/i' 'no se analizó']
#
# Columna: cd_total_mg_l
# Valores duplicados: ['<0.001' '<0.005' 'no se midió' nan '0.005' '0.007' '<0.002'
#  'no midieron este día' '<1.0' 'inaccesible' 'no muestreó'
#  'no se muestreó' 'en obra' 's/i' 'no se analizó']
#
# Columna: clorofila_a_ug_l
# Valores duplicados: ['<0.001' '<0.01' '0' '<0.010' '0.005' 'no se midió' nan '0.011' '0.018'
#  '0.001' '0.00119' '0.01246' '0.013' '0.00415' '0.009' '0.00237' '<10'
#  'no midieron este día' '350' '0.2' '0.6' '0.3' '0.0' '2.61' '3.85'
#  '<10.00' '<0.10' 'inaccesible' 'no muestreó' 'no se muestreó' '101.82'
#  '3.1' '2.79' 'en obra' '1.31' '0.87' '10.7' '5.99' '1.81' '0.35'
#  'falto un frasco' '0.45' '15.0' 's/i' '15.4' '10.3' '17.0']
#
# Columna: microcistina_ug_l
# Valores duplicados: ['<0.20' '<0.15' '<10.000' 'no se midió' nan '< 10.000' '\xa0<0.15'
#  'no midieron este día' '1' '0.2' 'Dato atípico' '>5.00' 'inaccesible'
#  'no muestreó' 'no se muestreó' '0.16' '0.19' '0.15' 'en obra' '0.41'
#  '0.27' '0.3' 's/i' '0.58']
#
# Columna: ica
# Valores duplicados: ['38' '34' '39' '47' 'no se midió' '46' '43' '49' '41' '26' '52' '42' '45'
#  '33' nan '37' '51' '50' '58' '40' '60' '44' '53' '48' '36' '64' '35' '57'
#  '28' '30' '65' '54' '55' '59' '31' '29' '56' '62' '61' '32' '67' '23'
#  '25' 'no se pudo calcular' 'inaccesible' 'no muestreó' 'no se muestreó'
#  'en obra' '74' '75' '76' '80' 's/i' '86' '63' '81' '27']
#
# Columna: calidad_de_agua
# Valores duplicados: ['Muy deteriorada' 'Extremadamente deteriorada' 'no se midió' nan
#  'Deteriorada' 'inaccesible' 'no muestreó' 'Muy deteriorada '
#  'no se muestreó' 'en obra' 'Levemente deteriorada' 's/i']
#
# Columna: gobierno_local
# Valores duplicados: [nan 'Avellaneda' 'Berisso' 'Berazategui' 'CABA' 'Ensenada' 'Quilmes'
#  'San Fernando' 'San Isidro' 'Tigre' 'Vicente López']
#
# Columna: sitio
# Valores duplicados: [nan 'Arroyo Santo Domingo' 'Escollera de propaneros' 'Playa La Bagliardi'
#  'Balneario Palo Blanco' 'Calle 14 y costa - salida cloaca'
#  'Costanera Hudson calle 63' 'Costanera norte espigón abanico'
#  'Club de pescadores' 'Reserva ecológica costanera sur playita'
#  'Camping Eva Perón' 'Ensenada prefectura isla Santiago' 'Espora 400 m'
#  'Del arca' 'Reserva ecológica' 'Perú puente'
#  'Canal Villanueva y río Luján' 'Río Luján y arroyo Caraguatá'
#  'Río Capitán y río San Antonio' 'Puerto de olivos espigón'
#  'Reserva ecológica ciudad universitaria costanera norte'
#  'Reserva ciudad universitaria: boca de entrada al humedal\xa0 desembocadura arroyo white'
#  'Reserva ciudad universitaria: marisma canal de marea principal'
#  'Reserva ciudad universitaria: humedal central \xa0 planicie de marea'
#  'Reserva ciudad universitaria: dique sur subsistema laguna'
#  'Boca cerrada (res. extra nat. punta Lara)']
#
# Columna: latitud
# Valores duplicados: [nan '-34.662.789' '-34.63' '-34.873.061' '-34.855.808' '-34.744.169'
#  '-34.753' '-34.547.089' '-34.563.231' '-34.612.761' '-34.820.711'
#  '-34.833.911' '-3.469.195' '-34.438.919' '-34.465.281' '-34.484.169'
#  '-34.408.061' '-34.384.169' '-34.375.561' '-34.505.531' '-34.535.878'
#  '-34.537.272' '-34.538.686' '-34.539.667' '-34.540.675' '-34.781.253']
#
# Columna: longitud
# Valores duplicados: [nan '-58.296.669' '-58.328.339' '-57.810.561' '-57.838.144' '-58.177.231'
#  '-58.108.281' '-58.430.231' '-58.404.119' '-58.340.611' '-57.965.319'
#  '-57.880.211' '-58.253.889' '-58.536.519' '-58.493.061' '-5.847.945'
#  '-58.590.839' '-58.632.511' '-58.558.619' '-58.473.719' '-58.445.933'
#  '-58.448.339' '-58.445.589' '-58.443.781' '-584.419' '-58.008.481']
#
# Columna: Poblacion_partido
# Valores duplicados: [nan '367.554' '100.930' '358.712' '3.121.707' '63.997' '633.391'
#  '171.616' '297.282' '446.949' '282.281']
#
# Columna: Personas_con_cloacas
# Valores duplicados: [nan '289.059' '47.630' '267.760' '3.049.672' '37.375' '469.008' '157.308'
#  '275.528' '144.834' '273.863']
#
# Columna: Actividad_principal
# Valores duplicados: [nan '"Producción de electricidad, gas y agua"'
#  '"Industria Manufacturera"'
#  '"Agricultura, ganadería, caza y silvicultura"'
#  '"servicios inmobiliarios, financieros y comercio"'
#  '"siderúrgica y refineria de petroleo"'
#  'Pesca explotación de criaderos de peces y granjas piscícolas y servicios conexos'
#  '"Actividad náutica"'
#  '"Explotación de minas y canteras con el 11,53%. Asimismo, es el segundo en participación en el rubro construcción"'
#  '"La industria metalúrgica y la actividad maderera"']
#
# Columna: Agricultura, ganadería, caza y silvicultura
# Valores duplicados: [nan  3.  1.  5.  2.  0.  4.]
#
# Columna: Pesca explotación de criaderos de peces y granjas piscícolas y servicios conexos
# Valores duplicados: [nan  3.  2.  1.  7.  5.  4.  6.]
#
# Columna: Explotación de minas y canteras
# Valores duplicados: [nan  3.  0.  1.  4.  2.]
#
# Columna: Industria Manufacturera
# Valores duplicados: [nan  2.  7.  3.  5.  6.  4.  1.]
#
# Columna: Electricidad, gas y agua
# Valores duplicados: [nan  1.  6.  2.  7.  3.  5.  4.]
#
# Columna: Construcción
# Valores duplicados: [nan  5.  6.  2.  7.  1.  3.  4.]
#
# Columna: Servicios
# Valores duplicados: [nan  6.  3.  2.  5.  1.  4.  7.]

# %% [markdown]
# **Valores faltantes - Datos vacios o con NaN**

# %% [markdown]
# Este código analiza un DataFrame y genera una tabla resumen que muestra cuántos datos faltantes tiene cada columna. Lo que hace es calcular cuántos valores son NaN, cuántos son cadenas vacías "", y luego suma ambos para obtener el total de faltantes. A partir de eso, también calcula el porcentaje que representan esos valores faltantes en relación al total de filas del DataFrame.
#
# El resultado es una tabla con cuatro columnas: una con la cantidad de valores NaN, otra con la cantidad de celdas vacías como texto, otra con el total combinado de valores faltantes, y una última con el porcentaje de datos incompletos. Esta tabla se muestra con un estilo visual que aplica una escala de color que va del verde al azul para resaltar visualmente las columnas con más valores faltantes. Cuanto más alto es el valor, más oscuro es el color de fondo.
#
# Además, la columna que muestra el porcentaje de faltantes aplica un formato especial: si ese porcentaje supera el 50%, el valor aparece resaltado en rojo y en negrita. Esto permite identificar rápidamente qué variables están críticamente incompletas y podrían requerir limpieza o eliminación.

# %%
# Calcular valores faltantes
nan_counts = df.isna().sum()
empty_counts = (df == "").sum()
total_faltantes = df.isna() | (df == "")
total_missing_counts = total_faltantes.sum()
porcentaje = (total_missing_counts / len(df) * 100)

# Crear resumen
summary = pd.DataFrame({
    "Valores NaN": nan_counts,
    "Vacíos ('')": empty_counts,
    "Total Faltantes": total_missing_counts,
    "Porcentaje (%)": porcentaje
})

# Función para resaltar en rojo si el porcentaje es crítico (> 50%)
def resaltar_porcentaje(col):
    return ['color: red; font-weight: bold' if v > 50 else '' for v in col]

# Aplicar estilos
summary.style\
    .background_gradient(cmap="BuGn")\
    .format({"Porcentaje (%)": "{:.2f}"})\
    .apply(resaltar_porcentaje, subset=["Porcentaje (%)"])\
    .set_caption("Resumen de Datos Faltantes")\
    .set_properties(**{'text-align': 'center'})
# Out:
# <style type="text/css">
# #T_f5a3d_row0_col0, #T_f5a3d_row0_col2, #T_f5a3d_row0_col3, #T_f5a3d_row1_col0, #T_f5a3d_row1_col2, #T_f5a3d_row1_col3, #T_f5a3d_row3_col0, #T_f5a3d_row3_col2, #T_f5a3d_row3_col3 {
#   background-color: #f0f9fb;
#   color: #000000;
#   text-align: center;
# }
# #T_f5a3d_row0_col1, #T_f5a3d_row1_col1, #T_f5a3d_row2_col0, #T_f5a3d_row2_col1, #T_f5a3d_row2_col2, #T_f5a3d_row2_col3, #T_f5a3d_row3_col1, #T_f5a3d_row4_col1, #T_f5a3d_row5_col1, #T_f5a3d_row6_col1, #T_f5a3d_row7_col1, #T_f5a3d_row8_col1, #T_f5a3d_row9_col1, #T_f5a3d_row10_col1, #T_f5a3d_row11_col1, #T_f5a3d_row12_col1, #T_f5a3d_row13_col1, #T_f5a3d_row14_col1, #T_f5a3d_row15_col1, #T_f5a3d_row16_col1, #T_f5a3d_row17_col1, #T_f5a3d_row18_col1, #T_f5a3d_row19_col1, #T_f5a3d_row20_col1, #T_f5a3d_row21_col1, #T_f5a3d_row22_col1, #T_f5a3d_row23_col1, #T_f5a3d_row24_col1, #T_f5a3d_row25_col1, #T_f5a3d_row26_col1, #T_f5a3d_row27_col1, #T_f5a3d_row28_col1, #T_f5a3d_row29_col1, #T_f5a3d_row30_col1, #T_f5a3d_row31_col1, #T_f5a3d_row32_col1, #T_f5a3d_row33_col1, #T_f5a3d_row34_col1, #T_f5a3d_row35_col1, #T_f5a3d_row36_col1, #T_f5a3d_row37_col1, #T_f5a3d_row38_col1, #T_f5a3d_row39_col1, #T_f5a3d_row40_col1, #T_f5a3d_row41_col1, #T_f5a3d_row42_col1, #T_f5a3d_row43_col1, #T_f5a3d_row44_col1 {
#   background-color: #f7fcfd;
#   color: #000000;
#   text-align: center;
# }
# #T_f5a3d_row4_col0, #T_f5a3d_row4_col2, #T_f5a3d_row4_col3, #T_f5a3d_row5_col0, #T_f5a3d_row5_col2, #T_f5a3d_row5_col3, #T_f5a3d_row6_col0, #T_f5a3d_row6_col2, #T_f5a3d_row6_col3, #T_f5a3d_row8_col0, #T_f5a3d_row8_col2, #T_f5a3d_row8_col3, #T_f5a3d_row15_col0, #T_f5a3d_row15_col2, #T_f5a3d_row15_col3, #T_f5a3d_row16_col0, #T_f5a3d_row16_col2, #T_f5a3d_row16_col3, #T_f5a3d_row17_col0, #T_f5a3d_row17_col2, #T_f5a3d_row17_col3, #T_f5a3d_row18_col0, #T_f5a3d_row18_col2, #T_f5a3d_row18_col3, #T_f5a3d_row19_col0, #T_f5a3d_row19_col2, #T_f5a3d_row19_col3, #T_f5a3d_row20_col0, #T_f5a3d_row20_col2, #T_f5a3d_row20_col3, #T_f5a3d_row25_col0, #T_f5a3d_row25_col2, #T_f5a3d_row25_col3, #T_f5a3d_row27_col0, #T_f5a3d_row27_col2, #T_f5a3d_row27_col3, #T_f5a3d_row28_col0, #T_f5a3d_row28_col2, #T_f5a3d_row28_col3 {
#   background-color: #eaf7fa;
#   color: #000000;
#   text-align: center;
# }
# #T_f5a3d_row7_col0, #T_f5a3d_row7_col2, #T_f5a3d_row7_col3 {
#   background-color: #e7f6f9;
#   color: #000000;
#   text-align: center;
# }
# #T_f5a3d_row9_col0, #T_f5a3d_row9_col2, #T_f5a3d_row9_col3 {
#   background-color: #e8f6fa;
#   color: #000000;
#   text-align: center;
# }
# #T_f5a3d_row10_col0, #T_f5a3d_row10_col2, #T_f5a3d_row10_col3, #T_f5a3d_row11_col0, #T_f5a3d_row11_col2, #T_f5a3d_row11_col3, #T_f5a3d_row12_col0, #T_f5a3d_row12_col2, #T_f5a3d_row12_col3, #T_f5a3d_row13_col0, #T_f5a3d_row13_col2, #T_f5a3d_row13_col3, #T_f5a3d_row22_col0, #T_f5a3d_row22_col2, #T_f5a3d_row22_col3, #T_f5a3d_row23_col0, #T_f5a3d_row23_col2, #T_f5a3d_row23_col3, #T_f5a3d_row24_col0, #T_f5a3d_row24_col2, #T_f5a3d_row24_col3, #T_f5a3d_row26_col0, #T_f5a3d_row26_col2, #T_f5a3d_row26_col3 {
#   background-color: #ebf7fa;
#   color: #000000;
#   text-align: center;
# }
# #T_f5a3d_row14_col0, #T_f5a3d_row14_col2, #T_f5a3d_row14_col3, #T_f5a3d_row21_col0, #T_f5a3d_row21_col2, #T_f5a3d_row21_col3 {
#   background-color: #e9f7fa;
#   color: #000000;
#   text-align: center;
# }
# #T_f5a3d_row29_col0, #T_f5a3d_row29_col2, #T_f5a3d_row29_col3 {
#   background-color: #e6f5f9;
#   color: #000000;
#   text-align: center;
# }
# #T_f5a3d_row30_col0, #T_f5a3d_row30_col2, #T_f5a3d_row30_col3 {
#   background-color: #dff3f5;
#   color: #000000;
#   text-align: center;
# }
# #T_f5a3d_row31_col0, #T_f5a3d_row31_col2, #T_f5a3d_row32_col0, #T_f5a3d_row32_col2, #T_f5a3d_row33_col0, #T_f5a3d_row33_col2, #T_f5a3d_row34_col0, #T_f5a3d_row34_col2, #T_f5a3d_row35_col0, #T_f5a3d_row35_col2, #T_f5a3d_row36_col0, #T_f5a3d_row36_col2, #T_f5a3d_row37_col0, #T_f5a3d_row37_col2 {
#   background-color: #29924f;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_f5a3d_row31_col3, #T_f5a3d_row32_col3, #T_f5a3d_row33_col3, #T_f5a3d_row34_col3, #T_f5a3d_row35_col3, #T_f5a3d_row36_col3, #T_f5a3d_row37_col3 {
#   background-color: #29924f;
#   color: #f1f1f1;
#   color: red;
#   font-weight: bold;
#   text-align: center;
# }
# #T_f5a3d_row38_col0, #T_f5a3d_row38_col2, #T_f5a3d_row39_col0, #T_f5a3d_row39_col2, #T_f5a3d_row40_col0, #T_f5a3d_row40_col2, #T_f5a3d_row41_col0, #T_f5a3d_row41_col2, #T_f5a3d_row42_col0, #T_f5a3d_row42_col2, #T_f5a3d_row43_col0, #T_f5a3d_row43_col2, #T_f5a3d_row44_col0, #T_f5a3d_row44_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   text-align: center;
# }
# #T_f5a3d_row38_col3, #T_f5a3d_row39_col3, #T_f5a3d_row40_col3, #T_f5a3d_row41_col3, #T_f5a3d_row42_col3, #T_f5a3d_row43_col3, #T_f5a3d_row44_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   color: red;
#   font-weight: bold;
#   text-align: center;
# }
# </style>
# <table id="T_f5a3d" class="dataframe">
#   <caption>Resumen de Datos Faltantes</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5a3d_level0_col0" class="col_heading level0 col0" >Valores NaN</th>
#       <th id="T_f5a3d_level0_col1" class="col_heading level0 col1" >Vacíos ('')</th>
#       <th id="T_f5a3d_level0_col2" class="col_heading level0 col2" >Total Faltantes</th>
#       <th id="T_f5a3d_level0_col3" class="col_heading level0 col3" >Porcentaje (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5a3d_level0_row0" class="row_heading level0 row0" >orden</th>
#       <td id="T_f5a3d_row0_col0" class="data row0 col0" >24</td>
#       <td id="T_f5a3d_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_f5a3d_row0_col2" class="data row0 col2" >24</td>
#       <td id="T_f5a3d_row0_col3" class="data row0 col3" >3.92</td>
#     </tr>
#     <tr>
#       <th id="T_f5a3d_level0_row1" class="row_heading level0 row1" >sitios</th>
#       <td id="T_f5a3d_row1_col0" class="data row1 col0" >24</td>
#       <td id="T_f5a3d_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_f5a3d_row1_col2" class="data row1 col2" >24</td>
#       <td id="T_f5a3d_row1_col3" class="data row1 col3" >3.92</td>
#     </tr>
#     <tr>
#       <th id="T_f5a3d_level0_row2" class="row_heading level0 row2" >codigo</th>
#       <td id="T_f5a3d_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_f5a3d_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_f5a3d_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_f5a3d_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_f5a3d_level0_row3" class="row_heading level0 row3" >fecha</th>
#       <td id="T_f5a3d_row3_col0" class="data row3 col0" >24</td>
#       <td id="T_f5a3d_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_f5a3d_row3_col2" class="data row3 col2" >24</td>
#       <td id="T_f5a3d_row3_col3" class="data row3 col3" >3.92</td>
#     </tr>
#     <tr>
#       <th id="T_f5a3d_level0_row4" class="row_heading level0 row4" >año</th>
#       <td id="T_f5a3d_row4_col0" class="data row4 col0" >40</td>
#       <td id="T_f5a3d_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_f5a3d_row4_col2" class="data row4 col2" >40</td>
#       <td id="T_f5a3d_row4_col3" class="data row4 col3" >6.53</td>
#     </tr>
#     <tr>
#       <th id="T_f5a3d_level0_row5" class="row_heading level0 row5" >campaña</th>
#       <td id="T_f5a3d_row5_col0" class="data row5 col0" >40</td>
#       <td id="T_f5a3d_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_f5a3d_row5_col2" class="data row5 col2" >40</td>
#       <td id="T_f5a3d_row5_col3" class="data row5 col3" >6.53</td>
#     </tr>
#     <tr>
#       <th id="T_f5a3d_level0_row6" class="row_heading level0 row6" >tem_agua</th>
#       <td id="T_f5a3d_row6_col0" class="data row6 col0" >41</td>
#       <td id="T_f5a3d_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_f5a3d_row6_col2" class="data row6 col2" >41</td>
#       <td id="T_f5a3d_row6_col3" class="data row6 col3" >6.69</td>
#     </tr>
#     <tr>
#       <th id="T_f5a3d_level0_row7" class="row_heading level0 row7" >tem_aire</th>
#       <td id="T_f5a3d_row7_col0" class="data row7 col0" >52</td>
#       <td id="T_f5a3d

# %% [markdown]
# **Resumen estadistico**

# %% [markdown]
# Al ejecutar el resumen estadístico del dataset, el objetivo principal es obtener una visión general cuantitativa y cualitativa de cada variable. Esto incluye información como: la cantidad de datos disponibles, los valores únicos, la moda, la media, la mediana, los cuartiles, el mínimo y el máximo, así como la desviación estándar para las variables numéricas.
#
# Este análisis permite identificar rápidamente la distribución y características principales de los datos, detectar posibles valores atípicos, entender la diversidad o repetición en variables categóricas, y evaluar la calidad y completitud de la información.

# %%
# Resumen estadistico
resumen = df.describe(include='all')

# Renombrar índices al español
resumen.rename(index={
    'count': 'Cantidad de datos',
    'unique': 'Valores únicos',
    'top': 'Valor más frecuente',
    'freq': 'Frecuencia',
    'mean': 'Promedio',
    'std': 'Desviación estándar',
    'min': 'Mínimo',
    '25%': 'Percentil 25',
    '50%': 'Mediana (Percentil 50)',
    '75%': 'Percentil 75',
    'max': 'Máximo'
}, inplace=True)

# Función para alternar colores en filas
def estilo_tabla(s):
    colores = ['#f9f9f9', '#e0f7fa']
    return ['background-color: {}'.format(colores[i % 2]) for i in range(len(s))]

# Aplicar estilo y mostrar
styled_resumen = resumen.style.apply(estilo_tabla, axis=0)\
                             .set_properties(**{'font-weight': 'bold'}, subset=pd.IndexSlice[['Cantidad de datos', 'Valores únicos', 'Frecuencia', 'Desviación estándar'], :])\
                             .set_table_styles([{
                                'selector': 'th',
                                'props': [('background-color', '#00796b'), ('color', 'white'), ('font-weight', 'bold')]
                             }])

print("\nResumen estadístico")
display(styled_resumen)
# Out:
# Resumen estadístico
# <style type="text/css">
# #T_5504d th {
#   background-color: #00796b;
#   color: white;
#   font-weight: bold;
# }
# #T_5504d_row0_col0, #T_5504d_row0_col1, #T_5504d_row0_col2, #T_5504d_row0_col3, #T_5504d_row0_col4, #T_5504d_row0_col5, #T_5504d_row0_col6, #T_5504d_row0_col7, #T_5504d_row0_col8, #T_5504d_row0_col9, #T_5504d_row0_col10, #T_5504d_row0_col11, #T_5504d_row0_col12, #T_5504d_row0_col13, #T_5504d_row0_col14, #T_5504d_row0_col15, #T_5504d_row0_col16, #T_5504d_row0_col17, #T_5504d_row0_col18, #T_5504d_row0_col19, #T_5504d_row0_col20, #T_5504d_row0_col21, #T_5504d_row0_col22, #T_5504d_row0_col23, #T_5504d_row0_col24, #T_5504d_row0_col25, #T_5504d_row0_col26, #T_5504d_row0_col27, #T_5504d_row0_col28, #T_5504d_row0_col29, #T_5504d_row0_col30, #T_5504d_row0_col31, #T_5504d_row0_col32, #T_5504d_row0_col33, #T_5504d_row0_col34, #T_5504d_row0_col35, #T_5504d_row0_col36, #T_5504d_row0_col37, #T_5504d_row0_col38, #T_5504d_row0_col39, #T_5504d_row0_col40, #T_5504d_row0_col41, #T_5504d_row0_col42, #T_5504d_row0_col43, #T_5504d_row0_col44 {
#   background-color: #f9f9f9;
#   font-weight: bold;
# }
# #T_5504d_row1_col0, #T_5504d_row1_col1, #T_5504d_row1_col2, #T_5504d_row1_col3, #T_5504d_row1_col4, #T_5504d_row1_col5, #T_5504d_row1_col6, #T_5504d_row1_col7, #T_5504d_row1_col8, #T_5504d_row1_col9, #T_5504d_row1_col10, #T_5504d_row1_col11, #T_5504d_row1_col12, #T_5504d_row1_col13, #T_5504d_row1_col14, #T_5504d_row1_col15, #T_5504d_row1_col16, #T_5504d_row1_col17, #T_5504d_row1_col18, #T_5504d_row1_col19, #T_5504d_row1_col20, #T_5504d_row1_col21, #T_5504d_row1_col22, #T_5504d_row1_col23, #T_5504d_row1_col24, #T_5504d_row1_col25, #T_5504d_row1_col26, #T_5504d_row1_col27, #T_5504d_row1_col28, #T_5504d_row1_col29, #T_5504d_row1_col30, #T_5504d_row1_col31, #T_5504d_row1_col32, #T_5504d_row1_col33, #T_5504d_row1_col34, #T_5504d_row1_col35, #T_5504d_row1_col36, #T_5504d_row1_col37, #T_5504d_row1_col38, #T_5504d_row1_col39, #T_5504d_row1_col40, #T_5504d_row1_col41, #T_5504d_row1_col42, #T_5504d_row1_col43, #T_5504d_row1_col44, #T_5504d_row3_col0, #T_5504d_row3_col1, #T_5504d_row3_col2, #T_5504d_row3_col3, #T_5504d_row3_col4, #T_5504d_row3_col5, #T_5504d_row3_col6, #T_5504d_row3_col7, #T_5504d_row3_col8, #T_5504d_row3_col9, #T_5504d_row3_col10, #T_5504d_row3_col11, #T_5504d_row3_col12, #T_5504d_row3_col13, #T_5504d_row3_col14, #T_5504d_row3_col15, #T_5504d_row3_col16, #T_5504d_row3_col17, #T_5504d_row3_col18, #T_5504d_row3_col19, #T_5504d_row3_col20, #T_5504d_row3_col21, #T_5504d_row3_col22, #T_5504d_row3_col23, #T_5504d_row3_col24, #T_5504d_row3_col25, #T_5504d_row3_col26, #T_5504d_row3_col27, #T_5504d_row3_col28, #T_5504d_row3_col29, #T_5504d_row3_col30, #T_5504d_row3_col31, #T_5504d_row3_col32, #T_5504d_row3_col33, #T_5504d_row3_col34, #T_5504d_row3_col35, #T_5504d_row3_col36, #T_5504d_row3_col37, #T_5504d_row3_col38, #T_5504d_row3_col39, #T_5504d_row3_col40, #T_5504d_row3_col41, #T_5504d_row3_col42, #T_5504d_row3_col43, #T_5504d_row3_col44, #T_5504d_row5_col0, #T_5504d_row5_col1, #T_5504d_row5_col2, #T_5504d_row5_col3, #T_5504d_row5_col4, #T_5504d_row5_col5, #T_5504d_row5_col6, #T_5504d_row5_col7, #T_5504d_row5_col8, #T_5504d_row5_col9, #T_5504d_row5_col10, #T_5504d_row5_col11, #T_5504d_row5_col12, #T_5504d_row5_col13, #T_5504d_row5_col14, #T_5504d_row5_col15, #T_5504d_row5_col16, #T_5504d_row5_col17, #T_5504d_row5_col18, #T_5504d_row5_col19, #T_5504d_row5_col20, #T_5504d_row5_col21, #T_5504d_row5_col22, #T_5504d_row5_col23, #T_5504d_row5_col24, #T_5504d_row5_col25, #T_5504d_row5_col26, #T_5504d_row5_col27, #T_5504d_row5_col28, #T_5504d_row5_col29, #T_5504d_row5_col30, #T_5504d_row5_col31, #T_5504d_row5_col32, #T_5504d_row5_col33, #T_5504d_row5_col34, #T_5504d_row5_col35, #T_5504d_row5_col36, #T_5504d_row5_col37, #T_5504d_row5_col38, #T_5504d_row5_col39, #T_5504d_row5_col40, #T_5504d_row5_col41, #T_5504d_row5_col42, #T_5504d_row5_col43, #T_5504d_row5_col44 {
#   background-color: #e0f7fa;
#   font-weight: bold;
# }
# #T_5504d_row2_col0, #T_5504d_row2_col1, #T_5504d_row2_col2, #T_5504d_row2_col3, #T_5504d_row2_col4, #T_5504d_row2_col5, #T_5504d_row2_col6, #T_5504d_row2_col7, #T_5504d_row2_col8, #T_5504d_row2_col9, #T_5504d_row2_col10, #T_5504d_row2_col11, #T_5504d_row2_col12, #T_5504d_row2_col13, #T_5504d_row2_col14, #T_5504d_row2_col15, #T_5504d_row2_col16, #T_5504d_row2_col17, #T_5504d_row2_col18, #T_5504d_row2_col19, #T_5504d_row2_col20, #T_5504d_row2_col21, #T_5504d_row2_col22, #T_5504d_row2_col23, #T_5504d_row2_col24, #T_5504d_row2_col25, #T_5504d_row2_col26, #T_5504d_row2_col27, #T_5504d_row2_col28, #T_5504d_row2_col29, #T_5504d_row2_col30, #T_5504d_row2_col31, #T_5504d_row2_col32, #T_5504d_row2_col33, #T_5504d_row2_col34, #T_5504d_row2_col35, #T_5504d_row2_col36, #T_5504d_row2_col37, #T_5504d_row2_col38, #T_5504d_row2_col39, #T_5504d_row2_col40, #T_5504d_row2_col41, #T_5504d_row2_col42, #T_5504d_row2_col43, #T_5504d_row2_col44, #T_5504d_row4_col0, #T_5504d_row4_col1, #T_5504d_row4_col2, #T_5504d_row4_col3, #T_5504d_row4_col4, #T_5504d_row4_col5, #T_5504d_row4_col6, #T_5504d_row4_col7, #T_5504d_row4_col8, #T_5504d_row4_col9, #T_5504d_row4_col10, #T_5504d_row4_col11, #T_5504d_row4_col12, #T_5504d_row4_col13, #T_5504d_row4_col14, #T_5504d_row4_col15, #T_5504d_row4_col16, #T_5504d_row4_col17, #T_5504d_row4_col18, #T_5504d_row4_col19, #T_5504d_row4_col20, #T_5504d_row4_col21, #T_5504d_row4_col22, #T_5504d_row4_col23, #T_5504d_row4_col24, #T_5504d_row4_col25, #T_5504d_row4_col26, #T_5504d_row4_col27, #T_5504d_row4_col28, #T_5504d_row4_col29, #T_5504d_row4_col30, #T_5504d_row4_col31, #T_5504d_row4_col32, #T_5504d_row4_col33, #T_5504d_row4_col34, #T_5504d_row4_col35, #T_5504d_row4_col36, #T_5504d_row4_col37, #T_5504d_row4_col38, #T_5504d_row4_col39, #T_5504d_row4_col40, #T_5504d_row4_col41, #T_5504d_row4_col42, #T_5504d_row4_col43, #T_5504d_row4_col44, #T_5504d_row6_col0, #T_5504d_row6_col1, #T_5504d_row6_col2, #T_5504d_row6_col3, #T_5504d_row6_col4, #T_5504d_row6_col5, #T_5504d_row6_col6, #T_5504d_row6_col7, #T_5504d_row6_col8, #T_5504d_row6_col9, #T_5504d_row6_col10, #T_5504d_row6_col11, #T_5504d_row6_col12, #T_5504d_row6_col13, #T_5504d_row6_col14, #T_5504d_row6_col15, #T_5504d_row6_col16, #T_5504d_row6_col17, #T_5504d_row6_col18, #T_5504d_row6_col19, #T_5504d_row6_col20, #T_5504d_row6_col21, #T_5504d_row6_col22, #T_5504d_row6_col23, #T_5504d_row6_col24, #T_5504d_row6_col25, #T_5504d_row6_col26, #T_5504d_row6_col27, #T_5504d_row6_col28, #T_5504d_row6_col29, #T_5504d_row6_col30, #T_5504d_row6_col31, #T_5504d_row6_col32, #T_5504d_row6_col33, #T_5504d_row6_col34, #T_5504d_row6_col35, #T_5504d_row6_col36, #T_5504d_row6_col37, #T_5504d_row6_col38, #T_5504d_row6_col39, #T_5504d_row6_col40, #T_5504d_row6_col41, #T_5504d_row6_col42, #T_5504d_row6_col43, #T_5504d_row6_col44, #T_5504d_row8_col0, #T_5504d_row8_col1, #T_5504d_row8_col2, #T_5504d_row8_col3, #T_5504d_row8_col4, #T_5504d_row8_col5, #T_5504d_row8_col6, #T_5504d_row8_col7, #T_5504d_row8_col8, #T_5504d_row8_col9, #T_5504d_row8_col10, #T_5504d_row8_col11, #T_5504d_row8_col12, #T_5504d_row8_col13, #T_5504d_row8_col14, #T_5504d_row8_col15, #T_5504d_row8_col16, #T_5504d_row8_col17, #T_5504d_row8_col18, #T_5504d_row8_col19, #T_5504d_row8_col20, #T_5504d_row8_col21, #T_5504d_row8_col22, #T_5504d_row8_col23, #T_5504d_row8_col24, #T_5504d_row8_col25, #T_5504d_row8_col26, #T_5504d_row8_col27, #T_5504d_row8_col28, #T_5504d_row8_col29, #T_5504d_row8_col30, #T_5504d_row8_col31, #T_5504d_row8_col32, #T_5504d_row8_col33, #T_5504d_row8_col34, #T_5504d_row8_col35, #T_5504d_row8_col36, #T_5504d_row8_col37, #T_5504d_row8_col38, #T_5504d_row8_col39, #T_5504d_row8_col40, #T_5504d_row8_col41, #T_5504d_row8_col42, #T_5504d_row8_col43, #T_5504d_row8_col44, #T_5504d_row10_col0, #T_5504d_row10_col1, #T_5504d_row10_col2, #T_5504d_row10_col3, #T_5504d_row10_col4, #T_5504d_row10_col5, #T_5504d_row10_col6, #T_5504d_row10_col7, #T_5504d_row10_col8, #T_5504d_row10_col9, #T_5504d_row10_col10, #T_5504d_row10_col11, #T_550 ...

# %% [markdown]
# Al observar el resumen estadístico del dataset, se puede observar que algunas columnas tienen una cantidad menor de datos registrados, lo que indica la presencia de valores faltantes. Por ejemplo, mientras que variables como el código o la fecha cuentan con casi todos los datos, otras como las mediciones químicas o físicas tienen menos registros completos.
#
# Se destaca que algunas columnas contienen valores categóricos, como el nombre de los sitios, la campaña o la estación del año, donde el valor más frecuente se repite muchas veces, reflejando condiciones comunes o datos estándar (como “invierno” o “Ausencia” en ciertas mediciones).
#
# En las columnas numéricas, el promedio, la desviación estándar y los percentiles muestran la distribución de los datos cuando están presentes, pero muchos valores son nulos, lo que implica que será necesario realizar un tratamiento especial para estos datos faltantes antes de hacer un análisis más profundo.

# %% [markdown]
# **Distribucion de las variables**

# %% [markdown]
# Los gráfico de histogramas muestra cómo se distribuyen los valores de cada variable numérica en el dataset. Permite visualizar si los datos están concentrados alrededor de ciertos rangos, si presentan sesgos hacia un extremo, o si existen valores atípicos o outliers. Además, ayuda a identificar la forma de la distribución por ejemplo, si es normal, sesgada o multimodal.

# %%
# Distribucion de variables
df.hist(bins=30, figsize=(18, 12))
plt.suptitle("Distribución de las variables", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# En Agricultura, ganadería, caza y silvicultura, las categorías 0 y 4 son las más frecuentes, con una presencia destacada también de las categorías 1 y 3. Esto indica que ciertas actividades o subsectores dentro de esta área son más comunes en los datos.
#
# En el sector de Pesca y explotación de criaderos de peces y granjas piscícolas, la categoría 4 tiene la mayor frecuencia, seguida por las categorías 2, 3 y 5, mostrando una concentración significativa en estas actividades específicas.
#
# Para la Explotación de minas y canteras, la categoría 0 es la que domina ampliamente, con la categoría 4 también teniendo un peso considerable. Esto refleja una concentración en ciertas actividades mineras o extractivas dentro del dataset.
#
# En la Industria manufacturera, la categoría 4 es claramente la más frecuente, seguida por las categorías 2, 6 y 7, lo que señala que una parte importante de la industria representada se centra en esos subsectores.
#
# En el sector de Electricidad, gas y agua, la categoría 5 destaca por su alta frecuencia, con presencia moderada de las categorías 1, 3 y 6, reflejando la distribución de actividades en servicios públicos.
#
# En Construcción, la categoría 3 tiene la mayor frecuencia, seguida por las categorías 1, 5 y 6, mostrando una variedad de subsectores con una concentración significativa en ciertos tipos de construcción.
#
# Finalmente, en Servicios, la categoría 4 es la más común, con las categorías 1, 3 y 6 también presentes en proporciones relevantes, indicando la diversidad dentro del sector servicios y ciertos subgrupos predominantes.

# %% [markdown]
# **Datos atipicos**

# %%
# Outliers
plt.figure(figsize=(18, 8))
sns.boxplot(data=df.select_dtypes(include=np.number))
plt.title("Detección de outliers en variables numéricas")
# Lista original de etiquetas del eje X
labels = df.select_dtypes(include=np.number).columns.tolist()

# Modificar etiquetas insertando saltos de línea
labels_wrapped = [
    label.replace(" ", "\n").replace(",", "\n")
    for label in labels
]

plt.xticks(ticks=range(len(labels_wrapped)), labels=labels_wrapped, rotation=0, ha='center')

plt.tight_layout()
plt.show()

# %% [markdown]
# El gráfico de cajas muestra la distribución de varias variables numéricas del dataset y permite identificar la presencia de outliers. En la mayoría de las variables relacionadas con sectores como agricultura, pesca, minería, industria manufacturera, electricidad, construcción y servicios, las cajas y los bigotes son relativamente compactos, lo que indica una distribución controlada y poca dispersión extrema.
#
# Sin embargo, la variable "orden" presenta una mayor dispersión y una caja más grande, sugiriendo que podría contener valores extremos o outliers que se alejan significativamente del resto de los datos. Para las otras variables, no se observan puntos fuera de los bigotes, lo que indica que no hay outliers evidentes o que estos son muy pocos y no se destacan claramente en el gráfico.

# %% [markdown]
# **Correlacion de variables**

# %% [markdown]
# Se muestra una matriz de correlación entre las variables numéricas del dataset, permitiendo visualizar qué tan relacionadas están entre sí. Los valores anotados indican la fuerza y dirección de la relación: valores cercanos a 1 o -1 muestran correlaciones fuertes positivas o negativas, respectivamente, mientras que valores cercanos a 0 indican poca o ninguna correlación.

# %%
# Correlacion entre variables
plt.figure(figsize=(16, 10))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Matriz de correlación")
plt.xticks(ticks=range(len(labels_wrapped)), labels=labels_wrapped, rotation=0)
plt.yticks(rotation=0)  # etiquetas verticales
plt.tight_layout()
plt.show()

# %% [markdown]
# En esta matriz se observa que algunas variables, como “Industria Manufacturera” y “Electricidad, gas y agua”, tienen una correlación positiva moderada (0.57), lo que indica que estas dos actividades tienden a aumentar o disminuir juntas. Por otro lado, “Industria Manufacturera” y “Servicios” muestran una correlación negativa fuerte (-0.73), lo que sugiere que cuando una variable aumenta, la otra tiende a disminuir.
#
# También destaca que “Explotación de minas y canteras” tiene una correlación positiva moderada con “Servicios” (0.43) y una correlación negativa con “Industria Manufacturera” (-0.52), lo que puede reflejar diferencias en la dinámica económica entre estos sectores.

# %% [markdown]
# CONCLUSION

# %% [markdown]
# El dataset contiene un total de 45 variables o features y 613 entradas o registros. Estas variables incluyen tanto datos numéricos como categóricos.
#
# En cuanto al tipo de datos, muchas columnas están clasificadas como objetos (object), lo que indica que son categóricas o texto. Sin embargo, algunas variables que deberían ser numéricas están almacenadas como texto, por lo que será necesario realizar conversiones para trabajar con datos cuantitativos continuos o discretos. También existen variables categóricas y posiblemente binarias dentro del conjunto.
#
# Se detectaron algunas filas duplicadas, aunque en cantidad limitada, y también valores repetidos dentro de columnas, lo cual es común en datos categóricos pero debe ser evaluado en variables numéricas para evitar redundancias.
#
# Respecto a los valores faltantes, varias columnas presentan datos incompletos, lo que implica que se deberá decidir cómo imputar esos valores o si es necesario eliminar registros o variables con muchos datos faltantes para mantener la calidad del análisis.
#
# El análisis de distribución mediante histogramas y boxplots reveló que algunas variables presentan outliers o valores atípicos, especialmente la variable “orden”, mientras que otras variables muestran distribuciones más compactas y homogéneas.
#
# La matriz de correlación indicó relaciones positivas y negativas entre ciertas variables, por ejemplo, una correlación positiva moderada entre “Industria Manufacturera” y “Electricidad, gas y agua”, y una correlación negativa fuerte entre “Industria Manufacturera” y “Servicios”. Estas relaciones ayudan a entender la interacción entre variables, identificar redundancias y seleccionar aquellas más relevantes para modelar o interpretar.
#
# Respecto a las unidades, es importante revisar y estandarizar aquellas variables numéricas que puedan estar expresadas en diferentes escalas o formatos, para evitar sesgos en el análisis o modelado.
